# %% [markdown]
# Dictionary Exercises

# %% [markdown]
# ![dict.jpg](attachment:dict.jpg)

# %%
#Q1 Create a dictionary for all participants in the JDA program.
#Keys should be the first letter in their names, Values should be their names.
#[Hint] dic={"l":(Leul),"J":(Jerry,Jainam)........}

#Answer1: 
dict_JDA_2023 = {"A":("Aakanksha","Abdulla","Aisha","Anjani"), "B":("Betsy","Bhaumik"), "C":("Cheuk","Christianah"),"D":("Dominic","Devinder"), "F":("Fatima","Femi"), "G":("Gurkirat"), "J":("Jankiben","Jay","Jefferson"), "K": ("Kai","Kameela","Konomi"), "M": ("Mahejabin","Md","Merin","Mohomed"), "N":("Nathan","Niloufar","Nitish","Nourcin"),"O":("Ohood","Olusegun"), "R":("Rajbir","Ramya","Reshma","Richard","Rispa","Ronak","Roya"), "S":("Sadhna","Said","Snoor","Sravani","Srishti","Stephen","Suja"), "V":("Valentina","Vu"), "Y":("Y","Yahia","Yuangang")}
dict_JDA_2023
# Out:
# {'A': ('Aakanksha', 'Abdulla', 'Aisha', 'Anjani'),
#  'B': ('Betsy', 'Bhaumik'),
#  'C': ('Cheuk', 'Christianah'),
#  'D': ('Dominic', 'Devinder'),
#  'F': ('Fatima', 'Femi'),
#  'G': 'Gurkirat',
#  'J': ('Jankiben', 'Jay', 'Jefferson'),
#  'K': ('Kai', 'Kameela', 'Konomi'),
#  'M': ('Mahejabin', 'Md', 'Merin', 'Mohomed'),
#  'N': ('Nathan', 'Niloufar', 'Nitish', 'Nourcin'),
#  'O': ('Ohood', 'Olusegun'),
#  'R': ('Rajbir', 'Ramya', 'Reshma', 'Richard', 'Rispa', 'Ronak', 'Roya'),
#  'S': ('Sadhna', 'Said', 'Snoor', 'Sravani', 'Srishti', 'Stephen', 'Suja'),
#  'V': ('Valentina', 'Vu'),
#  'Y': ('Y', 'Yahia', 'Yuangang')}

# %%
#Q2 What are the keys of your dictionary
#Answer2:
dict_JDA_2023.keys()
# Out:
# dict_keys(['A', 'B', 'C', 'D', 'F', 'G', 'J', 'K', 'M', 'N', 'O', 'R', 'S', 'V', 'Y'])

# %%
#Q3 What are the values of your dictionary
#Answer3:
dict_JDA_2023.values()
# Out:
# dict_values([('Aakanksha', 'Abdulla', 'Aisha', 'Anjani'), ('Betsy', 'Bhaumik'), ('Cheuk', 'Christianah'), ('Dominic', 'Devinder'), ('Fatima', 'Femi'), 'Gurkirat', ('Jankiben', 'Jay', 'Jefferson'), ('Kai', 'Kameela', 'Konomi'), ('Mahejabin', 'Md', 'Merin', 'Mohomed'), ('Nathan', 'Niloufar', 'Nitish', 'Nourcin'), ('Ohood', 'Olusegun'), ('Rajbir', 'Ramya', 'Reshma', 'Richard', 'Rispa', 'Ronak', 'Roya'), ('Sadhna', 'Said', 'Snoor', 'Sravani', 'Srishti', 'Stephen', 'Suja'), ('Valentina', 'Vu'), ('Y', 'Yahia', 'Yuangang')])

# %%
#Q4 Find participant's names that start with J,I,M,C,A
#Answer4:
print("Participants'names that start with A are: " + str(dict_JDA_2023["A"]))
print("Participants'names that start with C are: " + str(dict_JDA_2023["C"]))
print("Participants'names that start with M are: " + str(dict_JDA_2023["M"]))
#print("Participants'names that start with I are: " + str(dict_JDA_2023["I"]))
print("Participants'names that start with J are: " + str(dict_JDA_2023["J"]))
# Out:
# Participants'names that start with A are: ('Aakanksha', 'Abdulla', 'Aisha', 'Anjani')
# Participants'names that start with C are: ('Cheuk', 'Christianah')
# Participants'names that start with M are: ('Mahejabin', 'Md', 'Merin', 'Mohomed')
# Participants'names that start with J are: ('Jankiben', 'Jay', 'Jefferson')

# %%
#Q5 Add the following to your dictionary
# Key<(K,PD)>, Value<(Kristina)>
dict_JDA_2023["(K,PD)"]="Kristina"
dict_JDA_2023
# Out:
# {'A': ('Aakanksha', 'Abdulla', 'Aisha', 'Anjani'),
#  'B': ('Betsy', 'Bhaumik'),
#  'C': ('Cheuk', 'Christianah'),
#  'D': ('Dominic', 'Devinder'),
#  'F': ('Fatima', 'Femi'),
#  'G': 'Gurkirat',
#  'J': ('Jankiben', 'Jay', 'Jefferson'),
#  'K': ('Kai', 'Kameela', 'Konomi'),
#  'M': ('Mahejabin', 'Md', 'Merin', 'Mohomed'),
#  'N': ('Nathan', 'Niloufar', 'Nitish', 'Nourcin'),
#  'O': ('Ohood', 'Olusegun'),
#  'R': ('Rajbir', 'Ramya', 'Reshma', 'Richard', 'Rispa', 'Ronak', 'Roya'),
#  'S': ('Sadhna', 'Said', 'Snoor', 'Sravani', 'Srishti', 'Stephen', 'Suja'),
#  'V': ('Valentina', 'Vu'),
#  'Y': ('Y', 'Yahia', 'Yuangang'),
#  '(K,PD)': 'Kristina'}

# %%
#Q6 Find the length of your dictionary
len(dict_JDA_2023)
# Out:
# 16

# %%
#Q7 Add the following to your dictionary
# Key<(S,Instructor)>, Value<(Sarah)>
dict_JDA_2023["(S,Instructor)"]="Sarah"
dict_JDA_2023
# Out:
# {'A': ('Aakanksha', 'Abdulla', 'Aisha', 'Anjani'),
#  'B': ('Betsy', 'Bhaumik'),
#  'C': ('Cheuk', 'Christianah'),
#  'D': ('Dominic', 'Devinder'),
#  'F': ('Fatima', 'Femi'),
#  'G': 'Gurkirat',
#  'J': ('Jankiben', 'Jay', 'Jefferson'),
#  'K': ('Kai', 'Kameela', 'Konomi'),
#  'M': ('Mahejabin', 'Md', 'Merin', 'Mohomed'),
#  'N': ('Nathan', 'Niloufar', 'Nitish', 'Nourcin'),
#  'O': ('Ohood', 'Olusegun'),
#  'R': ('Rajbir', 'Ramya', 'Reshma', 'Richard', 'Rispa', 'Ronak', 'Roya'),
#  'S': ('Sadhna', 'Said', 'Snoor', 'Sravani', 'Srishti', 'Stephen', 'Suja'),
#  'V': ('Valentina', 'Vu'),
#  '(K,PD)': 'Kristina',
#  'Y': ('Y', 'Yahia', 'Yuangang'),
#  '(S,Instructor)': 'Sarah'}

# %%
#Q8 Find the length of your dictionary
len(dict_JDA_2023)
# Out:
# 15

# %%
#Q10 Create a new dictionary called synonyms_dic
#Q11 Add the synonyms of the following words to your dictionary
#Bad, Good, Awesome, Cold, Easy, Hard, Big, Small

synonyms_dic = {'Bad': 'Wrong', 'Good': 'Great', 'Awesome': 'Amazing', 'Cold': 'Chill', 'Easy': 'Simple', 'Hard': 'Difficult', 'Big': 'Enormous', 'Small': 'Tiny'}
synonyms_dic
# Out:
# {'Bad': 'Wrong',
#  'Good': 'Great',
#  'Awesome': 'Amazing',
#  'Cold': 'Chill',
#  'Easy': 'Simple',
#  'Hard': 'Difficult',
#  'Big': 'Enormous',
#  'Small': 'Tiny'}

# %%
#Q12 Use your dictionary to find the synonym of the following words
# Awesome, Easy, Small, Old

print(synonyms_dic["Awesome"])
print(synonyms_dic["Easy"])
print(synonyms_dic["Small"])
print(synonyms_dic["Cold"])
# Out:
# Amazing
# Simple
# Tiny
# Chill

# %%
#Q14 Print all values in synonyms_dic
print(synonyms_dic.values())
# Out:
# dict_values(['Wrong', 'Great', 'Amazing', 'Chill', 'Simple', 'Difficult', 'Enormous', 'Tiny'])

# %%
#Q15 Convert the below two lists into dictionary
Keys=["True","False"]
Values=[1,0]

#Answer15:
dic=dict(zip(Keys, Values))
print(dic)
# Out:
# {'True': 1, 'False': 0}

# %%
#Q16 Sum all the values in the following dictionary
income={'Jan':1000,'Feb':1500,'Mar':980,'April':1000}

#Answer16:
sum(income.values())
# Out:
# 4480

# %%
#Q17 Create the following dictionary encryption={10:"hungry", 101:"am", 110:"I"}

# What should be the decryption of the following code "110 101 10"?

#Answer17:
encryption={10:"hungry", 101:"am", 110:"I"}
decryption = sorted(encryption.values())
decryption
# Out:
# ['I', 'am', 'hungry']
