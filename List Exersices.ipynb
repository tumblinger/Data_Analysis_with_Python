# %%
#List Exersices

# %% [markdown]
# ![list.JPG](attachment:list.JPG)

# %%
#Q1 Create a tuple with all participant names in the JDA program

tuple_JDA = ("Aakanksha","Abdulla","Aisha","Anjani", "Betsy","Bhaumik","Cheuk","Christianah","Dominic","Devinder", "Fatima","Femi", "Gurkirat", "Jankiben","Jay","Jefferson", "Kai","Kameela","Konomi", "Mahejabin","Md","Merin","Mohomed", "Nathan","Niloufar","Nitish","Nourcin","Ohood","Olusegun", "Rajbir","Ramya","Reshma","Richard","Rispa","Ronak","Roya", "Sadhna","Said","Snoor","Sravani","Srishti","Stephen","Suja","Valentina","Vu","Y","Yahia","Yuangang")
print(tuple_JDA)
# Out:
# ('Aakanksha', 'Abdulla', 'Aisha', 'Anjani', 'Betsy', 'Bhaumik', 'Cheuk', 'Christianah', 'Dominic', 'Devinder', 'Fatima', 'Femi', 'Gurkirat', 'Jankiben', 'Jay', 'Jefferson', 'Kai', 'Kameela', 'Konomi', 'Mahejabin', 'Md', 'Merin', 'Mohomed', 'Nathan', 'Niloufar', 'Nitish', 'Nourcin', 'Ohood', 'Olusegun', 'Rajbir', 'Ramya', 'Reshma', 'Richard', 'Rispa', 'Ronak', 'Roya', 'Sadhna', 'Said', 'Snoor', 'Sravani', 'Srishti', 'Stephen', 'Suja', 'Valentina', 'Vu', 'Y', 'Yahia', 'Yuangang')

# %%
#Q2 Convert the tuple into a list called pps_L

pps_L = list(tuple_JDA)
print(pps_L)
type(pps_L)
# Out:
# ['Aakanksha', 'Abdulla', 'Aisha', 'Anjani', 'Betsy', 'Bhaumik', 'Cheuk', 'Christianah', 'Dominic', 'Devinder', 'Fatima', 'Femi', 'Gurkirat', 'Jankiben', 'Jay', 'Jefferson', 'Kai', 'Kameela', 'Konomi', 'Mahejabin', 'Md', 'Merin', 'Mohomed', 'Nathan', 'Niloufar', 'Nitish', 'Nourcin', 'Ohood', 'Olusegun', 'Rajbir', 'Ramya', 'Reshma', 'Richard', 'Rispa', 'Ronak', 'Roya', 'Sadhna', 'Said', 'Snoor', 'Sravani', 'Srishti', 'Stephen', 'Suja', 'Valentina', 'Vu', 'Y', 'Yahia', 'Yuangang']
# list

# %%
#Q3 What is the length of your list

len(pps_L)
# Out:
# 48

# %%
#Q4 Find the values stored in indexes [3],[5],[14],[30],[38]

print(pps_L[3])
print(pps_L[5])
print(pps_L[14])
print(pps_L[30])
print(pps_L[38])
# Out:
# Anjani
# Bhaumik
# Jay
# Ramya
# Snoor

# %%
#Q6 Add "Sarah" to your list


pps_L.append("Sarah")
# Out:
# ['Aakanksha',
#  'Abdulla',
#  'Aisha',
#  'Anjani',
#  'Betsy',
#  'Bhaumik',
#  'Cheuk',
#  'Christianah',
#  'Dominic',
#  'Devinder',
#  'Fatima',
#  'Femi',
#  'Gurkirat',
#  'Jankiben',
#  'Jay',
#  'Jefferson',
#  'Kai',
#  'Kameela',
#  'Konomi',
#  'Mahejabin',
#  'Md',
#  'Merin',
#  'Mohomed',
#  'Nathan',
#  'Niloufar',
#  'Nitish',
#  'Nourcin',
#  'Ohood',
#  'Olusegun',
#  'Rajbir',
#  'Ramya',
#  'Reshma',
#  'Richard',
#  'Rispa',
#  'Ronak',
#  'Roya',
#  'Sadhna',
#  'Said',
#  'Snoor',
#  'Sravani',
#  'Srishti',
#  'Stephen',
#  'Suja',
#  'Valentina',
#  'Vu',
#  'Y',
#  'Yahia',
#  'Yuangang',
#  'Sarah']

# %%
#Q5 Check if "Sarah" is in the list

"Sarah" in pps_L
# Out:
# True

# %%
#Q7 Check if "Bashir" is in the list

"Bashir" in pps_L
# Out:
# False

# %%
#Q9 Add "Bashir" to your list

pps_L.append("Bashir")
print(pps_L)
# Out:
# ['Aakanksha', 'Abdulla', 'Aisha', 'Anjani', 'Betsy', 'Bhaumik', 'Cheuk', 'Christianah', 'Dominic', 'Devinder', 'Fatima', 'Femi', 'Gurkirat', 'Jankiben', 'Jay', 'Jefferson', 'Kai', 'Kameela', 'Konomi', 'Mahejabin', 'Md', 'Merin', 'Mohomed', 'Nathan', 'Niloufar', 'Nitish', 'Nourcin', 'Ohood', 'Olusegun', 'Rajbir', 'Ramya', 'Reshma', 'Richard', 'Rispa', 'Ronak', 'Roya', 'Sadhna', 'Said', 'Snoor', 'Sravani', 'Srishti', 'Stephen', 'Suja', 'Valentina', 'Vu', 'Y', 'Yahia', 'Yuangang', 'Sarah', 'Bashir', 'Bashir']

# %%
#Q10 Find the index of the element "Sarah" in the list

pps_L.index("Sarah")
# Out:
# 48

# %%
#Q11 Change the value of the index in Q10 from "Sarah" to "Instructor"

pps_L[48] = "Instructor"
pps_L.remove("Bashir")
print(pps_L)
# Out:
# ['Aakanksha', 'Abdulla', 'Aisha', 'Anjani', 'Betsy', 'Bhaumik', 'Cheuk', 'Christianah', 'Dominic', 'Devinder', 'Fatima', 'Femi', 'Gurkirat', 'Jankiben', 'Jay', 'Jefferson', 'Kai', 'Kameela', 'Konomi', 'Mahejabin', 'Md', 'Merin', 'Mohomed', 'Nathan', 'Niloufar', 'Nitish', 'Nourcin', 'Ohood', 'Olusegun', 'Rajbir', 'Ramya', 'Reshma', 'Richard', 'Rispa', 'Ronak', 'Roya', 'Sadhna', 'Said', 'Snoor', 'Sravani', 'Srishti', 'Stephen', 'Suja', 'Valentina', 'Vu', 'Y', 'Yahia', 'Yuangang', 'Instructor']

# %%
pps_L.append("Bashir")

# %%
print(pps_L)
# Out:
# ['Aakanksha', 'Abdulla', 'Aisha', 'Anjani', 'Betsy', 'Bhaumik', 'Cheuk', 'Christianah', 'Dominic', 'Devinder', 'Fatima', 'Femi', 'Gurkirat', 'Jankiben', 'Jay', 'Jefferson', 'Kai', 'Kameela', 'Konomi', 'Mahejabin', 'Md', 'Merin', 'Mohomed', 'Nathan', 'Niloufar', 'Nitish', 'Nourcin', 'Ohood', 'Olusegun', 'Rajbir', 'Ramya', 'Reshma', 'Richard', 'Rispa', 'Ronak', 'Roya', 'Sadhna', 'Said', 'Snoor', 'Sravani', 'Srishti', 'Stephen', 'Suja', 'Valentina', 'Vu', 'Y', 'Yahia', 'Yuangang', 'Instructor', 'Bashir']

# %%
#Q12 Find the index of the element "Bashir" in the list

pps_L.index("Bashir")
# Out:
# 49

# %%
#Q13 Change the value of the index in Q12 from "Bashir" to "Peer-Mentor"

pps_L[49] = "Peer-Mentor"

# %%
print(pps_L)
# Out:
# ['Aakanksha', 'Abdulla', 'Aisha', 'Anjani', 'Betsy', 'Bhaumik', 'Cheuk', 'Christianah', 'Dominic', 'Devinder', 'Fatima', 'Femi', 'Gurkirat', 'Jankiben', 'Jay', 'Jefferson', 'Kai', 'Kameela', 'Konomi', 'Mahejabin', 'Md', 'Merin', 'Mohomed', 'Nathan', 'Niloufar', 'Nitish', 'Nourcin', 'Ohood', 'Olusegun', 'Rajbir', 'Ramya', 'Reshma', 'Richard', 'Rispa', 'Ronak', 'Roya', 'Sadhna', 'Said', 'Snoor', 'Sravani', 'Srishti', 'Stephen', 'Suja', 'Valentina', 'Vu', 'Y', 'Yahia', 'Yuangang', 'Instructor', 'Peer-Mentor']
