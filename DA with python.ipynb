# %% [markdown]
# # Python Activities, course "Data Analysis with Python"
# ![pic.JPG](attachment:pic.JPG)

# %%
import pandas as pd

# %%
table = pd.read_csv('cities.csv')
table
# Out:
#      LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0      41        5       59   "N"       80       39        0   "W"
# 1      42       52       48   "N"       97       23       23   "W"
# 2      46       35       59   "N"      120       30       36   "W"
# 3      42       16       12   "N"       71       48        0   "W"
# 4      43       37       48   "N"       89       46       11   "W"
# ..    ...      ...      ...   ...      ...      ...      ...   ...
# 123    39       31       12   "N"      119       48       35   "W"
# 124    50       25       11   "N"      104       39        0   "W"
# 125    40       10       48   "N"      122       14       23   "W"
# 126    40       19       48   "N"       75       55       48   "W"
# 127    41        9       35   "N"       81       14       23   "W"
#
#                  "City"  "State"
# 0          "Youngstown"       OH
# 1             "Yankton"       SD
# 2              "Yakima"       WA
# ...

# %%
##Add column df['Monitor']=[200,300,400,500]
df = table.head(10)
df
# Out:
#    LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0    41        5       59   "N"       80       39        0   "W"
# 1    42       52       48   "N"       97       23       23   "W"
# 2    46       35       59   "N"      120       30       36   "W"
# 3    42       16       12   "N"       71       48        0   "W"
# 4    43       37       48   "N"       89       46       11   "W"
# 5    36        5       59   "N"       80       15        0   "W"
# 6    49       52       48   "N"       97        9        0   "W"
# 7    39       11       23   "N"       78        9       36   "W"
# 8    34       14       24   "N"       77       55       11   "W"
# 9    39       45        0   "N"       75       33        0   "W"
#
#                "City"  "State"
# 0        "Youngstown"       OH
# 1           "Yankton"       SD
# 2            "Yakima"       WA
# 3         "Worcester"       MA
# 4   "Wisconsin Dells"       WI
# 5     "Winston-Salem"       NC
# ...

# %%
#Add a column to the dataframe
table = table.assign(CountryCode='Uknown')
table['NewCol'] = 0

# %%
table
# Out:
#      LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0      41        5       59   "N"       80       39        0   "W"
# 1      42       52       48   "N"       97       23       23   "W"
# 2      46       35       59   "N"      120       30       36   "W"
# 3      42       16       12   "N"       71       48        0   "W"
# 4      43       37       48   "N"       89       46       11   "W"
# ..    ...      ...      ...   ...      ...      ...      ...   ...
# 123    39       31       12   "N"      119       48       35   "W"
# 124    50       25       11   "N"      104       39        0   "W"
# 125    40       10       48   "N"      122       14       23   "W"
# 126    40       19       48   "N"       75       55       48   "W"
# 127    41        9       35   "N"       81       14       23   "W"
#
#                  "City"  "State" CountryCode  NewCol
# 0          "Youngstown"       OH      Uknown       0
# 1             "Yankton"       SD      Uknown       0
# ...

# %%
#Perform describe and info on dataframe
table.describe()
# Out:
#              LatD      "LatM"      "LatS"      "LonD"      "LonM"      "LonS"  \
# count  128.000000  128.000000  128.000000  128.000000  128.000000  128.000000
# mean    38.820312   30.765625   27.492188   93.250000   27.742188   26.960938
# std      5.200596   16.426158   18.977814   15.466499   16.927937   18.727807
# min     26.000000    1.000000    0.000000   71.000000    0.000000    0.000000
# 25%     35.000000   16.000000   11.000000   80.000000   14.000000   11.000000
# 50%     39.000000   31.000000   24.000000   89.500000   26.500000   23.500000
# 75%     42.250000   45.000000   47.000000  103.250000   40.250000   47.000000
# max     50.000000   59.000000   59.000000  123.000000   58.000000   59.000000
#
#        NewCol
# count   128.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0

# %%
#Perform describe and info on dataframe
table.describe(include='all')
# Out:
#               LatD      "LatM"      "LatS"  "NS"      "LonD"      "LonM"  \
# count   128.000000  128.000000  128.000000   128  128.000000  128.000000
# unique         NaN         NaN         NaN     1         NaN         NaN
# top            NaN         NaN         NaN   "N"         NaN         NaN
# freq           NaN         NaN         NaN   128         NaN         NaN
# mean     38.820312   30.765625   27.492188   NaN   93.250000   27.742188
# std       5.200596   16.426158   18.977814   NaN   15.466499   16.927937
# min      26.000000    1.000000    0.000000   NaN   71.000000    0.000000
# 25%      35.000000   16.000000   11.000000   NaN   80.000000   14.000000
# 50%      39.000000   31.000000   24.000000   NaN   89.500000   26.500000
# 75%      42.250000   45.000000   47.000000   NaN  103.250000   40.250000
# max      50.000000   59.000000   59.000000   NaN  123.000000   58.000000
#
#             "LonS"  "EW"          "City"  "State" CountryCode  NewCol
# ...

# %%
table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LatD         128 non-null    int64
#  1    "LatM"      128 non-null    int64
#  2    "LatS"      128 non-null    int64
#  3    "NS"        128 non-null    object
#  4    "LonD"      128 non-null    int64
#  5    "LonM"      128 non-null    int64
#  6    "LonS"      128 non-null    int64
#  7    "EW"        128 non-null    object
#  8    "City"      128 non-null    object
#  9    "State"     128 non-null    object
#  10  CountryCode  128 non-null    object
#  11  NewCol       128 non-null    int64
# dtypes: int64(7), object(5)
# memory usage: 12.1+ KB

# %%
#Export and save this data as cities1.csv
table.to_csv('cities1.csv')

# %% [markdown]
# # GoodBelly Dataset

# %%
pd.read_excel('GoodBelly-DataSet.xlsx')
# Out:
#                                            Unnamed: 0  \
# 0          Explanation of GoodBelly Sales Spreadsheet
# 1                                                 NaN
# 2   The data came from 126 Whole Foods stores over...
# 3                                                 NaN
# 4                                Variable Definitions
# 5                                                   1
# 6                                                   2
# 7                                                   3
# 8                                                   4
# 9                                                   5
# 10                                                  6
# 11                                                  7
# 12                                                  8
# 13                                                  9
#
#                                            Unnamed: 1
# 0                                                 NaN
# ...

# %%
# Read the second sheet of an Excel file into a dataframe
dbelly = pd.read_excel('GoodBelly-DataSet.xlsx', sheet_name=1)

# Print the first few rows of the dataframe
dbelly.head(20)
# Out:
#          Date Region                    Store  Units Sold  \
# 0  2010-05-04     FL  Biscayne (aka Aventura)  150.702088
# 1  2010-05-11     FL  Biscayne (aka Aventura)  197.403797
# 2  2010-05-18     FL  Biscayne (aka Aventura)  235.106172
# 3  2010-05-25     FL  Biscayne (aka Aventura)  226.692427
# 4  2010-06-01     FL  Biscayne (aka Aventura)  257.688151
# 5  2010-06-08     FL  Biscayne (aka Aventura)  132.957190
# 6  2010-06-15     FL  Biscayne (aka Aventura)  221.889969
# 7  2010-06-22     FL  Biscayne (aka Aventura)  245.881356
# 8  2010-06-29     FL  Biscayne (aka Aventura)  156.102535
# 9  2010-07-06     FL  Biscayne (aka Aventura)  200.103966
# 10 2010-07-13     FL  Biscayne (aka Aventura)  128.396003
# 11 2010-05-04     FL               Boca Raton  142.778210
# 12 2010-05-11     FL               Boca Raton  237.544554
# 13 2010-05-18     FL               Boca Raton  141.533297
# 14 2010-05-25     FL               Boca Raton  158.073949
# ...

# %%
#Find how many records this data frame has
length = len(dbelly)
print('This Database has ', length, 'records')
# Out:
# This Database has  1386 records

# %%
#How many elements are there?  
print('This table has ',dbelly.size, 'cells or elements')
# Out:
# This table has  16632 cells or elements

# %%
#What are the column names?
dbelly.columns
# Out:
# Index(['Date', 'Region', 'Store', 'Units Sold', 'Average Retail Price',
#        'Sales Rep', 'Endcap', 'Demo', 'Demo1-3', 'Demo4-5', 'Natural',
#        'Fitness'],
#       dtype='object')

# %%
#What types of columns do we have in this data frame?
dbelly.dtypes
# Out:
# Date                    datetime64[ns]
# Region                          object
# Store                           object
# Units Sold                     float64
# Average Retail Price           float64
# Sales Rep                        int64
# Endcap                           int64
# Demo                             int64
# Demo1-3                          int64
# Demo4-5                          int64
# Natural                          int64
# Fitness                          int64
# dtype: object

# %%
#Give the summary for the numeric columns in the dataset
dbelly.describe()
# Out:
#         Units Sold  Average Retail Price    Sales Rep       Endcap  \
# count  1386.000000           1386.000000  1386.000000  1386.000000
# mean    253.820718              4.107093     0.549784     0.038240
# std     110.998731              0.463828     0.497695     0.191843
# min      47.559852              2.889286     0.000000     0.000000
# 25%     189.995471              3.775714     0.000000     0.000000
# 50%     236.735266              4.096667     1.000000     0.000000
# 75%     295.804391              4.425067     1.000000     0.000000
# max    1041.200256              6.251538     1.000000     1.000000
#
#               Demo      Demo1-3      Demo4-5      Natural      Fitness
# count  1386.000000  1386.000000  1386.000000  1386.000000  1386.000000
# mean      0.058442     0.156566     0.075758     1.448773     2.476190
# std       0.234661     0.363522     0.264705     0.975092     1.592789
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# ...

# %%
#Calculate standard deviation for all numeric columns;
dbelly.std()
# Out:
# C:\Users\Valentina\AppData\Local\Temp\ipykernel_13756\3228288820.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dbelly.std()
# Date                    22 days 03:27:15.853934319
# Units Sold                              110.998731
# Average Retail Price                      0.463828
# Sales Rep                                 0.497695
# Endcap                                    0.191843
# Demo                                      0.234661
# Demo1-3                                   0.363522
# Demo4-5                                   0.264705
# Natural                                   0.975092
# Fitness                                   1.592789
# dtype: object

# %%
#What are the mean values of the first 50 records in the dataset?  
# Hint: use head() method to subset the first 50 records and then calculate the mean

bhead = dbelly.head(50)
bhead.mean()
# Out:
# C:\Users\Valentina\AppData\Local\Temp\ipykernel_13756\3700080408.py:5: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   bhead.mean()
# C:\Users\Valentina\AppData\Local\Temp\ipykernel_13756\3700080408.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   bhead.mean()
# Units Sold              186.280727
# Average Retail Price      4.128036
# Sales Rep                 0.000000
# Endcap                    0.100000
# Demo                      0.000000
# Demo1-3                   0.000000
# Demo4-5                   0.040000
# Natural                   1.300000
# Fitness                   1.560000
# dtype: float64
